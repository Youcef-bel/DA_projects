# %% [markdown]
# # Data Analyst Associate Practical Exam Submission
#
# **You can use any tool that you want to do your analysis and create visualizations. Use this template to write up your summary for submission.**
#
# You can use any markdown formatting you wish. If you are not familiar with Markdown, read the [Markdown Guide](https://s3.amazonaws.com/talent-assets.datacamp.com/Markdown+Guide.pdf) before you start.

# %% [markdown]
# ## Data Validation
# Describe the validation tasks you performed and what you found. Have you made any changes to the data to enable further analysis? Remember to describe what you did for every column in the data.
#
# *Write your description here*

# %% [markdown]
# The claims dataset has 98 rows and 8 columns. The first thing I did was checking duplicates in the "Claim ID" column but there were no duplicate rows. Then, I checked for missing values in the datasets, the only column that contain null values was the "Cause" column, I replaced null values with 'unknown'.
# Then, I converted the Claim Amount column values from text to integer, by deleting the 'R$' value and converting it into a number.
#
# **In** **general**:
# - There were 98 unique Claim ID with no duplicates, as expected.
# - There were 98 rows on the Time to Close column as integer, as expected.
# - There were 98 rows on the Claim Amount column as integers, after cleaning data.
# - There were 98 rows in Amount Paid column as float, as expected.
# - There were 4 unique locations, as expected.
# - There were 98 rows in the Individuals on the Claim column as integer, as expected.
# - There were 98 rows on the Linked Cases column as bool , as expected.
# - After cleaning the data, there were 98 rows on the Cause column as text.

# %% [markdown]
# ## Data Discovery and Visualization
# Describe what you found in the analysis and how the visualizations answer the customer questions in the project brief. In your description you should:
# - Include at least two different data visualizations to demonstrate the characteristics of single variables
# - Include at least one data visualization to demonstrate the relationship between two or more variables
# - Describe how your analysis has answered the business questions in the project brief
#
# *Write your description here*

# %% [markdown]
# ## How does the number of claims differ across locations?
# ##
# As we know before, there are four locations included in this data. The "SAO LUIS" location has the highest number of claims with 30 claims. This would suggest that the legal team should focus on this location for a better result. On the other hand, other locations have a close count number to "SAO LUIS". So, they shouldn't be ignored.

# %% [markdown]
# ![Sheet 2](Sheet%202.png)

# %% [markdown]
# ## What is the distribution of time to close claims?
# ##
# We have a right-skewed histogram chart that indicates how the number of days to close claims is distributed. Looking at all reviews, we can see that most of the claims took less than 1000 days to get closed. We can see some outliers that get more than 3000 and 3500 days but this is very uncommon. In worst cases, it won't take more than 2500 days to get the claim closed.

# %% [markdown]
# ![Sheet 1](Sheet%201.png)

# %% [markdown]
# ##  How does the average time to close claims differ by location?
# ##
# From the Area chart below, we can see that the average time to close claims range between 581.1 to 1026.3 days across locations. "NATAL" has the lowest average time to close claims, FORTALEZA has an average of 775.5 while RECIFE  has an average of 860.7 days. But, again, we can see that SAO LUIS has the highest average time close claims.

# %% [markdown]
# ![Sheet 5](Sheet%205.png)

# %% [markdown]
# To dig deeper into the average time range by location, a horizontal-bar chart has been used below. It indicates the total and the average time to close claims by location. I have excluded the previous outlying values presented in the histogram chart.
# Now, despite excluding outlying values, we still have SAO LUIS with the highest total time to close claims and the highest average time to close claims.
# ![Sheet 7](Sheet%207.png)

# %% [markdown]
# **In conclusion, we can tell that:**
# - SAO LUIS has the highest number of claims.
# - Most of the claims took less than 1000 days to get closed.
# - SAO LUIS has the highest average time to close claims.
# So, the legal team should focus on the SAO LUIS location because it has the highest number of claims and the highest average time to close those claims.

# %% [markdown]
# ## ✅ When you have finished...
# -  Publish your Workspace using the option on the left
# -  Check the published version of your report:
# 	-  Can you see everything you want us to grade?
#     -  Are all the graphics visible?
# -  Review the grading rubric. Have you included everything that will be graded?
# -  Head back to the [Certification Dashboard](https://app.datacamp.com/certification) to submit your practical exam
